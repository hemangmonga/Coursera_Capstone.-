# %% [markdown]
# # ANALYSIS TO FIND BEST CHINESE RESTAURANTS IN INDIA.

# %% [markdown]
# ### Importing necessary libraries.

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import requests
from bs4 import BeautifulSoup
# !pip install geocoder
import geocoder
import os
# !pip install folium
import folium # map rendering library
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
# Matplotlib and associated plotting modules
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
# %matplotlib inline


print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ### Function to get the geolocation of an address.

# %%
def geo_location(address):
    # get geo location of address
    try:
        geolocator = Nominatim(user_agent="ny_explorer")
        location = geolocator.geocode(address)
        latitude = location.latitude
        longitude = location.longitude
        return latitude,longitude
    except:
        pass

# %% [markdown]
# ### Function to interact with Foursquare API to get top 100 venues within a radius of 50000 meters for a given lattitude and longitude.
# ### Below function will return us venue id, venue name, and category.

# %%
def get_venues(lat,lng):
    
    #set variables
    radius=50000
    LIMIT=100
    CLIENT_ID = 'JXF12LQXS5KZGFAJA2H0EFCIFEGBWJIWX3ZVQIYNJ3OOXWO0'     # Foursquare ID
    CLIENT_SECRET = 'YMV5XNYVCB45Z4JUSGJM3YUWXXETGBMMOMNVEMXYJGAFJNP1' # Foursquare Secret
    VERSION = '20191225' # Foursquare API version
    
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
    
    # get all the data
    results = requests.get(url).json()
    venue_data=results["response"]['groups'][0]['items']
    venue_details=[]
    try:
        for row in venue_data:
            venue_id=row['venue']['id']
            venue_name=row['venue']['name']
            venue_category=row['venue']['categories'][0]['name']
            venue_details.append([venue_id,venue_name,venue_category])
    except KeyError:
        pass
    
    column_names=['ID','Name','Category']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df

# %% [markdown]
# ### function to get venue details like like count , rating , tip counts for a given venue id. This will be used for ranking

# %%
def get_venue_details(venue_id):
        
    CLIENT_ID = 'JXF12LQXS5KZGFAJA2H0EFCIFEGBWJIWX3ZVQIYNJ3OOXWO0' # your Foursquare ID
    CLIENT_SECRET = 'YMV5XNYVCB45Z4JUSGJM3YUWXXETGBMMOMNVEMXYJGAFJNP1' # your Foursquare Secret
    VERSION = '20191225' # Foursquare API version
    
    
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/{}?&client_id={}&client_secret={}&v={}'.format(
            venue_id,
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION)
    
    # get all the data
    results = requests.get(url).json()
    venue_data=results['response']['venue']
    venue_details=[]
    try:
        venue_id=venue_data['id']
        venue_name=venue_data['name']
        venue_likes=venue_data['likes']['count']
        venue_rating=venue_data['rating']
        venue_tips=venue_data['tips']['count']
        venue_details.append([venue_id,venue_name,venue_likes,venue_rating,venue_tips])
    except KeyError:
        pass
        
    column_names=['ID','Name','Likes','Rating','Tips']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df

# %% [markdown]
# ### Function to get India Data  containg State, city, Latitude and Longitude.

# %%
def get_india_data():
    url='https://raw.githubusercontent.com/hemangmonga/Coursera_Capstone.-/master/in.json'
    resp=requests.get(url).json()
    # all data is present in features label
    features=resp
    
    # define the dataframe columns
    column_names = ['State', 'city', 'Latitude', 'Longitude'] 
    # instantiate the dataframe
    india_data = pd.DataFrame(columns=column_names)
    
    for data in features:
        State = data['admin'] 
        city = data['city']
        neighborhood_lat = data['lat']
        neighborhood_lon = data['lng']
    
        india_data = india_data.append({'State': State,
                                          'city': city,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)
        
        
    return india_data

# %% [markdown]
# ### And Cleaning the Data.

# %%
df = get_india_data()

for i in range(0,len(df.city)):
    for j in df.city[i]:
        if j == 'ā':
            df.city[i] = df.city[i].replace('ā','a')
            
        elif j == 'Ā':
            df.city[i] = df.city[i].replace('Ā','A')
       
        elif j == 'ī':
            df.city[i] = df.city[i].replace('ī','i')
            
        elif j == 'ū':
            df.city[i] = df.city[i].replace('ū','u')
            
for i in range(0,len(df.State)):
    for j in df.State[i]:
        if j == 'ā':
            df.State[i] = df.State[i].replace('ā','a')
            
        elif j == 'Ā':
            df.State[i] = df.State[i].replace('Ā','A')
       
        elif j == 'ī':
            df.State[i] = df.State[i].replace('ī','i')
            
        elif j == 'ū':
            df.State[i] = df.State[i].replace('ū','u')
            
df.head()
# Out:
#          State       city   Latitude  Longitude
# 0  Maharashtra     Mumbai  18.987807  72.836447
# 1        Delhi      Delhi  28.651952  77.231495
# 2  West Bengal    Kolkata  22.562627  88.363044
# 3  Tamil Nadu     Chennai  13.084622  80.248357
# 4    Karnataka  Bengaluru  12.977063  77.587106

# %%
df.shape
# Out:
# (212, 4)

# %% [markdown]
# ###  Plotting a Graph to see No. of Cities in each State.

# %%
plt.figure(figsize=(9,5), dpi = 100)
# title
plt.title('Number of cities for each State in India')
#On x-axis
plt.xlabel('State', fontsize = 15)
#On y-axis
plt.ylabel('No.of cities', fontsize=15)
#giving a bar plot
df.groupby('State')['city'].count().plot(kind='bar')
#legend
plt.legend()
#displays the plot
plt.show()

# %% [markdown]
# ### Calling Functions to see no. of Chinese Restaurants in Each City.

# %%
column_names=['State', 'city', 'ID','Name']
Chinese_rest=pd.DataFrame(columns=column_names)
count=1
for row in df.values.tolist():
    State, city, Latitude, Longitude=row
    venues = get_venues(Latitude,Longitude)
    chinese_resturants=venues[venues['Category']=='Chinese Restaurant']   
    print('(',count,'/',len(df),')','Chinese Resturants in '+city+', '+State+':'+str(len(chinese_resturants)))
    for resturant_detail in chinese_resturants.values.tolist():
        id, name , category=resturant_detail
        Chinese_rest = Chinese_rest.append({'State': State,
                                                'city': city, 
                                                'ID': id,
                                                'Name' : name
                                               }, ignore_index=True)
    count+=1
# Out:
# ( 1 / 212 ) Chinese Resturants in Mumbai, Maharashtra:1
# ( 2 / 212 ) Chinese Resturants in Delhi, Delhi:1
# ( 3 / 212 ) Chinese Resturants in Kolkata, West Bengal:8
# ( 4 / 212 ) Chinese Resturants in Chennai, Tamil Nadu :2
# ( 5 / 212 ) Chinese Resturants in Bengaluru, Karnataka:0
# ( 6 / 212 ) Chinese Resturants in Hyderabad, Andhra Pradesh:1
# ( 7 / 212 ) Chinese Resturants in Ahmadabad, Gujarat:1
# ( 8 / 212 ) Chinese Resturants in Haora, West Bengal:8
# ( 9 / 212 ) Chinese Resturants in Pune, Maharashtra:0
# ( 10 / 212 ) Chinese Resturants in Surat, Gujarat:3
# ( 11 / 212 ) Chinese Resturants in Mardanpur, Uttar Pradesh:0
# ( 12 / 212 ) Chinese Resturants in Rampura, Rajasthan:0
# ( 13 / 212 ) Chinese Resturants in Lucknow, Uttar Pradesh:0
# ( 14 / 212 ) Chinese Resturants in Nara, Maharashtra:1
# ( 15 / 212 ) Chinese Resturants in Patna, Bihar:1
# ( 16 / 212 ) Chinese Resturants in Indore, Madhya Pradesh:1
# ( 17 / 212 ) Chinese Resturants in Vadodara, Gujarat:0
# ( 18 / 212 ) Chinese Resturants in Bhopal, Madhya Pradesh:0
# ( 19 / 212 ) Chinese Resturants in Coimbatore, Tamil Nadu :0
# ( 20 / 212 ) Chinese Resturants in Ludhiana, Punjab:0
# ( 21 / 212 ) Chinese Resturants in Agra, Uttar Pradesh:0
# ( 22 / 212 ) Chinese Resturants in Kalyan, Maharashtra:1
# ( 23 / 212 ) Chinese Resturants in Vishakhapatnam, Andhra Pradesh:0
# ( 24 / 212 ) Chinese Resturants in Kochi, Kerala:0
# ( 25 / 212 ) Chinese Resturants in Nasik, Maharashtra:0
# ( 26 / 212 ) Chinese Resturants in Meerut, Uttar Pradesh:0
# ( 27 / 212 ) Chinese Resturants in Faridabad, Haryana:1
# ( 28 / 212 ) Chinese Resturants in Varanasi, Uttar Pradesh:0
# ( 29 / 212 ) Chinese Resturants in Ghaziabad, Uttar Pradesh:1
# ( 30 / 212 ) Chinese Resturants in Asansol, West Bengal:1
# ( 31 / 212 ) Chinese Resturants in Jamshedpur, Jharkhand:0
# ( 32 / 212 ) Chinese Resturants in Madurai, Tamil Nadu :0
# ( 33 / 212 ) Chinese Resturants in Jabalpur, Madhya Pradesh:1
# ( 34 / 212 ) Chinese Resturants in Rajkot, Gujarat:0
# ( 35 / 212 ) Chinese Resturants in Dhanbad, Jharkhand:0
# ( 36 / 212 ) Chinese Resturants in Amritsar, Punjab:0
# ( 37 / 212 ) Chinese Resturants in Warangal, Andhra Pradesh:0
# ( 38 / 212 ) Chinese Resturants in Allahabad, Uttar Pradesh:0
# ( 39 / 212 ) Chinese Resturants in Srinagar, Jammu and Kashmir:1
# ( 40 / 212 ) Chinese Resturants in Aurangabad, Maharashtra:0
# ( 41 / 212 ) Chinese Resturants in Bhilai, Chhattisgarh:0
# ( 42 / 212 ) Chinese Resturants in Solapur, Maharashtra:0
# ( 43 / 212 ) Chinese Resturants in Ranchi, Jharkhand:0
# ( 44 / 212 ) Chinese Resturants in Jodhpur, Rajasthan:0
# ( 45 / 212 ) Chinese Resturants in Guwahati, Assam:2
# ( 46 / 212 ) Chinese Resturants in Chandigarh, Chandigarh:2
# ( 47 / 212 ) Chinese Resturants in Gwalior, Madhya Pradesh:0
# ( 48 / 212 ) Chinese Resturants in Thiruvananthapuram, Kerala:1
# ( 49 / 212 ) Chinese Resturants in Tiruchchirappalli, Tamil Nadu :0
# ( 50 / 212 ) Chinese Resturants in Hubli, Karnataka:0
# ( 51 / 212 ) Chinese Resturants in Mysore, Karnataka:1
# ( 52 / 212 ) Chinese Resturants in Raipur, Chhattisgarh:0
# ( 53 / 212 ) Chinese Resturants in Salem, Tamil Nadu :1
# ( 54 / 212 ) Chinese Resturants in Bhubaneshwar, Odisha:1
# ( 55 / 212 ) Chinese Resturants in Kota, Rajasthan:0
# ( 56 / 212 ) Chinese Resturants in Jhansi, Uttar Pradesh:0
# ( 57 / 212 ) Chinese Resturants in Bareilly, Uttar Pradesh:0
# ( 58 / 212 ) Chinese Resturants in Aligarh, Uttar Pradesh:0
# ( 59 / 212 ) Chinese Resturants in Bhiwandi, Maharashtra:1
# ( 60 / 212 ) Chinese Resturants in Jammu, Jammu and Kashmir:0
# ( 61 / 212 ) Chinese Resturants in Moradabad, Uttar Pradesh:0
# ( 62 / 212 ) Chinese Resturants in Mangalore, Karnataka:0
# ( 63 / 212 ) Chinese Resturants in Kolhapur, Maharashtra:0
# ( 64 / 212 ) Chinese Resturants in Amravati, Maharashtra:0
# ( 65 / 212 ) Chinese Resturants in Dehra Dun, Uttarakhand:1
# ( 66 / 212 ) Chinese Resturants in Malegaon Camp, Maharashtra:0
# ( 67 / 212 ) Chinese Resturants in Nellore, Andhra Pradesh:0
# ( 68 / 212 ) Chinese Resturants in Gopalpur, Uttar Pradesh:0
# ( 69 / 212 ) Chinese Resturants in Shimoga, Karnataka:0
# ( 70 / 212 ) Chinese Resturants in Tiruppur, Tamil Nadu :0
# ( 71 / 212 ) Chinese Resturants in Raurkela, Odisha:0
# ( 72 / 212 ) Chinese Resturants in Nanded, Maharashtra:0
# ( 73 / 212 ) Chinese Resturants in Belgaum, Karnataka:0
# ( 74 / 212 ) Chinese Resturants in Sangli, Maharashtra:0
# ( 75 / 212 ) Chinese Resturants in Chanda, Maharashtra:0
# ( 76 / 212 ) Chinese Resturants in Ajmer, Rajasthan:0
# ( 77 / 212 ) Chinese Resturants in Cuttack, Odisha:1
# ( 78 / 212 ) Chinese Resturants in Bikaner, Rajasthan:0
# ( 79 / 212 ) Chinese Resturants in Bhavnagar, Gujarat:0
# ( 80 / 212 ) Chinese Resturants in Hisar, Haryana:0
# ( 81 / 212 ) Chinese Resturants in Bilaspur, Chhattisgarh:0
# ( 82 / 212 ) Chinese Resturants in Tirunelveli, Tamil Nadu :0
# ( 83 / 212 ) Chinese Resturants in Guntur, Andhra Pradesh:0
# ( 84 / 212 ) Chinese Resturants in Shiliguri, West Bengal:1
# ( 85 / 212 ) Chinese Resturants in Ujjain, Madhya Pradesh:1
# ( 86 / 212 ) Chinese Resturants in Davangere, Karnataka:0
# ( 87 / 212 ) Chinese Resturants in Akola, Maharashtra:0
# ( 88 / 212 ) Chinese Resturants in Saharanpur, Uttar Pradesh:0
# ( 89 / 212 ) Chinese Resturants in Gulbarga, Karnataka:0
# ( 90 / 212 ) Chinese Resturants in Bhatpara, West Bengal:8
# ( 91 / 212 ) Chinese Resturants in Dhulia, Maharashtra:0
# ( 92 / 212 ) Chinese Resturants in Udaipur, Rajasthan:0
# ( 93 / 212 ) Chinese Resturants in Bellary, Karnataka:0
# ( 94 / 212 ) Chinese Resturants in Tuticorin, Tamil Nadu :0
# ( 95 / 212 ) Chinese Resturants in Kurnool, Andhra Pradesh:0
# ( 96 / 212 ) Chinese Resturants in Gaya, Bihar:0
# ( 97 / 212 ) Chinese Resturants in Sikar, Rajasthan:0
# ( 98 / 212 ) Chinese Resturants in Tumkur, Karnataka:0
# ( 99 / 212 ) Chinese Resturants in Kollam, Kerala:1
# ( 100 / 212 ) Chinese Resturants in Ahmadnagar, Maharashtra:0
# ( 101 / 212 ) Chinese Resturants in Bhilwara, Rajasthan:0
# ( 102 / 212 ) Chinese Resturants in Nizamabad, Andhra Pradesh:0
# ( 103 / 212 ) Chinese Resturants in Parbhani, Maharashtra:0
# ( 104 / 212 ) Chinese Resturants in Shillong, Meghalaya:1
# ( 105 / 212 ) Chinese Resturants in Latur, Maharashtra:0
# ( 106 / 212 ) Chinese Resturants in Rajapalaiyam, Tamil Nadu :0
# ( 107 / 212 ) Chinese Resturants in Bhagalpur, Bihar:0
# ( 108 / 212 ) Chinese Resturants in Muzaffarnagar, Uttar Pradesh:0
# ( 109 / 212 ) Chinese Resturants in Muzaffarpur, Bihar:0
# ( 110 / 212 ) Chinese Resturants in Mathura, Uttar Pradesh:0
# ( 111 / 212 ) Chinese Resturants in Patiala, Punjab:0
# ( 112 / 212 ) Chinese Resturants in Saugor, Madhya Pradesh:0
# ( 113 / 212 ) Chinese Resturants in Brahmapur, Odisha:0
# ( 114 / 212 ) Chinese Resturants in Shahbazpur, Uttar Pradesh:0
# ( 115 / 212 ) Chinese Resturants in New Delhi, Delhi:1
# ( 116 / 212 ) Chinese Resturants in Rohtak, Haryana:0
# ( 117 / 212 ) Chinese Resturants in Samlaipadar, Odisha:0
# ( 118 / 212 ) Chinese Resturants in Ratlam, Madhya Pradesh:0
# ( 119 / 212 ) Chinese Resturants in Firozabad, Uttar Pradesh:0
# ( 120 / 212 ) Chinese Resturants in Rajahmundry, Andhra Pradesh:0
# ( 121 / 212 ) Chinese Resturants in Barddhaman, West Bengal:0
# ( 122 / 212 ) Chinese Resturants in Bidar, Karnataka:0
# ( 123 / 212 ) Chinese Resturants in Bamanpuri, Uttar Pradesh:0
# ( 124 / 212 ) Chinese Resturants in Kakinada, Andhra Pradesh:0
# ( 125 / 212 ) Chinese Resturants in Panipat, Haryana:0
# ( 126 / 212 ) Chinese Resturants in Khammam, Andhra Pradesh:0
# ( 127 / 212 ) Chinese Resturants in Bhuj, Gujarat:0
# ( 128 / 212 ) Chinese Resturants in Karimnagar, Andhra Pradesh:0
# ( 129 / 212 ) Chinese Resturants in Tirupati, Andhra Pradesh:0
# ( 130 / 212 ) Chinese Resturants in Hospet, Karnataka:0
# ( 131 / 212 ) Chinese Resturants in Chikka Mandya, Karnataka:1
# ( 132 / 212 ) Chinese Resturants in Alwar, Rajasthan:0
# ( 133 / 212 ) Chinese Resturants in Aizawl, Mizoram:0
# ( 134 / 212 ) Chinese Resturants in Bijapur, Karnataka:0
# ( 135 / 212 ) Chinese Resturants in Imphal, Manipur:0
# ( 136 / 212 ) Chinese Resturants in Tharati Etawah, Uttar Pradesh:0
# ( 137 / 212 ) Chinese Resturants in Raichur, Karnataka:0
# ( 138 / 212 ) Chinese Resturants in Pathankot, Punjab:0
# ( 139 / 212 ) Chinese Resturants in Chirala, Andhra Pradesh:0
# ( 140 / 212 ) Chinese Resturants in Sonipat, Haryana:0
# ( 141 / 212 ) Chinese Resturants in Mirzapur, Uttar Pradesh:0
# ( 142 / 212 ) Chinese Resturants in Hapur, Uttar Pradesh:0
# ( 143 / 212 ) Chinese Resturants in Porbandar, Gujarat:0
# ( 144 / 212 ) Chinese Resturants in Bharatpur, Rajasthan:0
# ( 145 / 212 ) Chinese Resturants in Puducherry, Puducherry:0
# ( 146 / 212 ) Chinese Resturants in Karnal, Haryana:0
# ( 147 / 212 ) Chinese Resturants in Nagercoil, Tamil Nadu :1
# ( 148 / 212 ) Chinese Resturants in Thanjavur, Tamil Nadu :0
# ( 149 / 212 ) Chinese Resturants in Pali, Rajasthan:0
# ( 150 / 212 ) Chinese Resturants in Agartala, Tripura:0
# ( 151 / 212 ) Chinese Resturants in Ongole, Andhra Pradesh:0
# ( 152 / 212 ) Chinese Resturants in Puri, Odisha:0
# ( 153 / 212 ) Chinese Resturants in Dindigul, Tamil Nadu :0
# ( 154 / 212 ) Chinese Resturants in Haldia, West Bengal:0
# ( 155 / 212 ) Chinese Resturants in Bulandshahr, Uttar Pradesh:0
# ( 156 / 212 ) Chinese Resturants in Purnea, Bihar:0
# ( 157 / 212 ) Chinese Resturants in Proddatur, Andhra Pradesh:0
# ( 158 / 212 ) Chinese Resturants in Gurgaon, Haryana:1
# ( 159 / 212 ) Chinese Resturants in Khanapur, Maharashtra:0
# ( 160 / 212 ) Chinese Resturants in Machilipatnam, Andhra Pradesh:0
# ( 161 / 212 ) Chinese Resturants in Bhiwani, Haryana:0
# ( 162 / 212 ) Chinese Resturants in Nandyal, Andhra Pradesh:0
# ( 163 / 212 ) Chinese Resturants in Bhusaval, Maharashtra:0
# ( 164 / 212 ) Chinese Resturants in Bharauri, Uttar Pradesh:0
# ( 165 / 212 ) Chinese Resturants in Tonk, Rajasthan:0
# ( 166 / 212 ) Chinese Resturants in Sirsa, Haryana:0
# ( 167 / 212 ) Chinese Resturants in Vizianagaram, Andhra Pradesh:0
# ( 168 / 212 ) Chinese Resturants in Vellore, Tamil Nadu :2
# ( 169 / 212 ) Chinese Resturants in Alappuzha, Kerala:1
# ( 170 / 212 ) Chinese Resturants in Shimla, Himachal Pradesh:1
# ( 171 / 212 ) Chinese Resturants in Hindupur, Andhra Pradesh:0
# ( 172 / 212 ) Chinese Resturants in Baramula, Jammu and Kashmir:1
# ( 173 / 212 ) Chinese Resturants in Bakshpur, Uttar Pradesh:0
# ( 174 / 212 ) Chinese Resturants in Dibrugarh, Assam:0
# ( 175 / 212 ) Chinese Resturants in Saidapur, Uttar Pradesh:0
# ( 176 / 212 ) Chinese Resturants in Navsari, Gujarat:3
# ( 177 / 212 ) Chinese Resturants in Budaun, Uttar Pradesh:0
# ( 178 / 212 ) Chinese Resturants in Cuddalore, Tamil Nadu :0
# ( 179 / 212 ) Chinese Resturants in Haripur, Punjab:0
# ( 180 / 212 ) Chinese Resturants in Krishnapuram, Tamil Nadu :0
# ( 181 / 212 ) Chinese Resturants in Fyzabad, Uttar Pradesh:0
# ( 182 / 212 ) Chinese Resturants in Silchar, Assam:0
# ( 183 / 212 ) Chinese Resturants in Ambala, Haryana:2
# ( 184 / 212 ) Chinese Resturants in Krishnanagar, West Bengal:0
# ( 185 / 212 ) Chinese Resturants in Kolar, Karnataka:0
# ( 186 / 212 ) Chinese Resturants in Kumbakonam, Tamil Nadu :0
# ( 187 / 212 ) Chinese Resturants in Tiruvannamalai, Tamil Nadu :0
# ( 188 / 212 ) Chinese Resturants in Pilibhit, Uttar Pradesh:0
# ( 189 / 212 ) Chinese Resturants in Abohar, Punjab:0
# ( 190 / 212 ) Chinese Resturants in Port Blair, Andaman and Nicobar Islands:0
# ( 191 / 212 ) Chinese Resturants in Alipur Duar, West Bengal:0
# ( 192 / 212 ) Chinese Resturants in Hatisa, Uttar Pradesh:0
# ( 193 / 212 ) Chinese Resturants in Valparai, Tamil Nadu :0
# ( 194 / 212 ) Chinese Resturants in Aurangabad, Bihar:0
# ( 195 / 212 ) Chinese Resturants in Kohima, Nagaland:0
# ( 196 / 212 ) Chinese Resturants in Gangtok, Sikkim:0
# ( 197 / 212 ) Chinese Resturants in Karur, Tamil Nadu :0
# ( 198 / 212 ) Chinese Resturants in Jorhat, Assam:0
# ( 199 / 212 ) Chinese Resturants in Panaji, Goa:0
# ( 200 / 212 ) Chinese Resturants in Saidpur, Jammu and Kashmir:1
# ( 201 / 212 ) Chinese Resturants in Tezpur, Assam:0
# ( 202 / 212 ) Chinese Resturants in Itanagar, Arunachal Pradesh:0
# ( 203 / 212 ) Chinese Resturants in Daman, Daman and Diu:0
# ( 204 / 212 ) Chinese Resturants in Silvassa, Dadra and Nagar Haveli:0
# ( 205 / 212 ) Chinese Resturants in Diu, Daman and Diu:0
# ( 206 / 212 ) Chinese Resturants in Dispur, Assam:2
# ( 207 / 212 ) Chinese Resturants in Kavaratti, Lakshadweep:0
# ( 208 / 212 ) Chinese Resturants in Calicut, Kerala:0
# ( 209 / 212 ) Chinese Resturants in Kagaznagar, Andhra Pradesh:0
# ( 210 / 212 ) Chinese Resturants in Jaipur, Rajasthan:0
# ( 211 / 212 ) Chinese Resturants in Ghandinagar, Gujarat:1
# ( 212 / 212 ) Chinese Resturants in Panchkula, Haryana:2

# %%
Chinese_rest.head()
# Out:
#          State     city                        ID        Name
# 0  Maharashtra   Mumbai  4b5dc6e6f964a520166b29e3   Ming Yang
# 1        Delhi    Delhi  4ed0f96e6c2510ace194f2f7     Hawkers
# 2  West Bengal  Kolkata  4dfa2b8aae60f95f8225b9c9    Big Boss
# 3  West Bengal  Kolkata  4cdea62ef8cdb1f7a35e8c12  Golden Joy
# 4  West Bengal  Kolkata  534fda5e498e8696570687b8    Yauatcha

# %%
Chinese_rest.shape
# Out:
# (77, 4)

# %% [markdown]
# ### Plotting a graph for No. of Chinese Restaurants in each state of India.

# %%
plt.figure(figsize=(9,5), dpi = 100)
# title
plt.title('Number of chinese Resturants for each State in India')
#On x-axis
plt.xlabel('State', fontsize = 15)
#On y-axis
plt.ylabel('No.of Chinese Resturants', fontsize=15)
#giving a bar plot
Chinese_rest.groupby('State')['ID'].count().plot(kind='bar')
#legend
plt.legend()
#displays the plot
plt.show()

# %% [markdown]
# ### Plotting A Graph for 5 cities with highest no. of Chinese Restaurants.

# %%
plt.figure(figsize=(9,5), dpi = 100)
# title
plt.title('Number of Chinese Resturants for Top 5 Cities in India')
#On x-axis
plt.xlabel('City', fontsize = 15)
#On y-axis
plt.ylabel('No.of Chinese Resturants', fontsize=15)
#giving a bar plot
Chinese_rest.groupby('city')['ID'].count().nlargest(5).plot(kind='bar')
#legend
plt.legend()
#displays the plot
plt.show()

# %% [markdown]
# ### Best Chinese Restaurants in Kolkata.

# %%
Chinese_rest[Chinese_rest.city == 'Kolkata']
# Out:
#          State     city                        ID                   Name
# 2  West Bengal  Kolkata  4dfa2b8aae60f95f8225b9c9               Big Boss
# 3  West Bengal  Kolkata  4cdea62ef8cdb1f7a35e8c12             Golden Joy
# 4  West Bengal  Kolkata  534fda5e498e8696570687b8               Yauatcha
# 5  West Bengal  Kolkata  4d19f40dbb488cfa6628c1d4     Beijing Restaurant
# 6  West Bengal  Kolkata  4d7b9c9e8f89224b06c89326  Red Hot Chilli Pepper
# 7  West Bengal  Kolkata  4bbcaf18f57ba593d810adb9            Chinoiserie
# 8  West Bengal  Kolkata  4c0651d9761ac9b60ab92074         Mainland China
# 9  West Bengal  Kolkata  4bded98ffe0e62b52eff0506       O2 Hotel Kolkata

# %%
#prepare city list that contains Chinese resturants
column_names=['State', 'city', 'ID','Name','Likes','Rating','Tips']
chinese_rest_stats=pd.DataFrame(columns=column_names)
count=1


for row in Chinese_rest.values.tolist():
    State,city,ID,Name=row
    try:
        venue_details=get_venue_details(ID)
        print(venue_details)
        id,name,likes,rating,tips=venue_details.values.tolist()[0]
    except:                                                                                                
        print('No data available for id=',ID)
        # we will assign 0 value for these resturants as they may have been 
        #recently opened or details does not exist in FourSquare Database
        id,name,likes,rating,tips=[0]*5
    print('(',count,'/',len(Chinese_rest),')','processed')
    chinese_rest_stats = chinese_rest_stats.append({'State': State,
                                                'city': city, 
                                                'ID': id,
                                                'Name' : name,
                                                'Likes' : likes,
                                                'Rating' : rating,
                                                'Tips' : tips
                                               }, ignore_index=True)
    count+=1
# Out:
#                          ID      Name  Likes  Rating  Tips
# 0  4dfa2b8aae60f95f8225b9c9  Big Boss     22     8.5     8
# ( 1 / 77 ) processed

# %%
rating_df = chinese_rest_stats
# rating_df

# %%
rating_df.head()
# Out:
#             State       city                        ID            Name Likes  \
# 0          Odisha    Cuttack  4da84de37aba67f9d9619c29  Mainland China    10
# 1     West Bengal  Shiliguri                         0               0     0
# 2  Madhya Pradesh     Ujjain  4f235911e4b01b0c5e5b28ff  Chopstick City    11
# 3     West Bengal   Bhatpara  4dfa2b8aae60f95f8225b9c9        Big Boss    22
# 4     West Bengal   Bhatpara  4cdea62ef8cdb1f7a35e8c12      Golden Joy    20
#
#    Rating Tips
# 0     7.8    7
# 1     0.0    0
# 2     8.4    4
# 3     8.5    8
# 4     8.4   12

# %%
rating_df.shape
# Out:
# (77, 7)

# %% [markdown]
# ### Saving this list of Best Chinese Restaurants in a csv File.

# %%
rating_df.to_csv('Chinese_rest_stats.csv', index = False)

# %%
rating_df = pd.read_csv('Chinese_rest_stats.csv')
rating_df
# Out:
#                 State                city                        ID  \
# 0              Odisha             Cuttack  4da84de37aba67f9d9619c29
# 1         West Bengal           Shiliguri                         0
# 2      Madhya Pradesh              Ujjain  4f235911e4b01b0c5e5b28ff
# 3         West Bengal            Bhatpara  4dfa2b8aae60f95f8225b9c9
# 4         West Bengal            Bhatpara  4cdea62ef8cdb1f7a35e8c12
# 5         West Bengal            Bhatpara  4d19f40dbb488cfa6628c1d4
# 6         West Bengal            Bhatpara  534fda5e498e8696570687b8
# 7         West Bengal            Bhatpara  4d7b9c9e8f89224b06c89326
# 8         West Bengal            Bhatpara  4bbcaf18f57ba593d810adb9
# 9         West Bengal            Bhatpara  4c0651d9761ac9b60ab92074
# 10        West Bengal            Bhatpara  4bded98ffe0e62b52eff0506
# 11             Kerala              Kollam  511fc03ae4b0e893f70f5386
# 12          Meghalaya            Shillong  5249ae70498e6fde52bcd7b0
# 13              Delhi           New Delhi  4ed0f96e6c2510ace194f2f7
# 14          Karnataka       Chikka Mandya  4ea98b949adf64e06c6a6f7e
# 15        Tamil Nadu            Nagercoil  4d77d03f013060fc81e79c05
# 16            Haryana             Gurgaon  4ed0f96e6c2510ace194f2f7
# 17        Tamil Nadu              Vellore  4dabf6444b22f071ead89760
# 18        Tamil Nadu              Vellore  4d9f2b2847ad370495a14ae5
# 19             Kerala           Alappuzha  4ce7bb2cbaa6a1cd9569296c
# 20   Himachal Pradesh              Shimla  4d564519c0432d4311f3f6b1
# 21  Jammu and Kashmir            Baramula  4f4a481ce4b0c132f2baab67
# 22            Gujarat             Navsari  4bb5453cf562ef3b0ec82e97
# 23            Gujarat             Navsari  4f466f74e4b0068c290ee6e4
# 24            Gujarat             Navsari  50a7a41fe4b099e2bc052c9f
# 25            Haryana              Ambala  4b8a5453f964a520bb6832e3
# 26            Haryana              Ambala  4c022361f423a5936670ce16
# 27  Jammu and Kashmir             Saidpur  4f4a481ce4b0c132f2baab67
# 28              Assam              Dispur  4f153c4be4b0725fef6080c2
# 29              Assam              Dispur  4f16cf6be4b0fd2953b69899
# 30            Gujarat         Ghandinagar  4bfb77858d30d13a7d1f0418
# 31            Haryana           Panchkula  4b8a5453f964a520bb6832e3
# 32            Haryana           Panchkula  4c022361f423a5936670ce16
# 33        Maharashtra              Mumbai  4b5dc6e6f964a520166b29e3
# 34              Delhi               Delhi  4ed0f96e6c2510ace194f2f7
# 35        West Bengal             Kolkata  4cdea62ef8cdb1f7a35e8c12
# 36        West Bengal             Kolkata  534fda5e498e8696570687b8
# 37        West Bengal             Kolkata  4d19f40dbb488cfa6628c1d4
# 38        West Bengal             Kolkata  4d7b9c9e8f89224b06c89326
# 39        West Bengal             Kolkata  4bbcaf18f57ba593d810adb9
# 40        West Bengal             Kolkata  4c0651d9761ac9b60ab92074
# 41        West Bengal             Kolkata  4bded98ffe0e62b52eff0506
# 42        Tamil Nadu              Chennai  505d8693e4b05434c0f2cbf3
# 43     Andhra Pradesh           Hyderabad  5050c114e4b0694f643d178e
# 44            Gujarat           Ahmadabad  4bfb77858d30d13a7d1f0418
# 45        West Bengal               Haora  4dfa2b8aae60f95f8225b9c9
# 46        West Bengal               Haora  534fda5e498e8696570687b8
# 47        West Bengal               Haora  4cdea62ef8cdb1f7a35e8c12
# 48        West Bengal               Haora  4d7b9c9e8f89224b06c89326
# 49        West Bengal               Haora  4d19f40dbb488cfa6628c1d4
# 50        West Bengal               Haora  4bbcaf18f57ba593d810adb9
# 51        West Bengal               Haora  4bded98ffe0e62b52eff0506
# 52            Gujarat               Surat  4bb5453cf562ef3b0ec82e97
# 53            Gujarat               Surat  4f466f74e4b0068c290ee6e4
# 54            Gujarat               Surat  50a7a41fe4b099e2bc052c9f
# 55              Bihar               Patna  4e6c7ec6b0fba3f50e549413
# 56     Madhya Pradesh              Indore  4f235911e4b01b0c5e5b28ff
# 57        Maharashtra              Kalyan  4b5dc6e6f964a520166b29e3
# 58            Haryana           Faridabad  4ed0f96e6c2510ace194f2f7
# 59        Maharashtra                Nara  4b4c36f5f964a520b7af26e3
# 60        West Bengal               Haora  4c0651d9761ac9b60ab92074
# 61      Uttar Pradesh           Ghaziabad  4ed0f96e6c2510ace194f2f7
# 62        West Bengal             Asansol  50817180e4b0bf87bfcd566a
# 63     Madhya Pradesh            Jabalpur  4e09875081dc6d6d36a69683
# 64  Jammu and Kashmir            Srinagar  4f4a481ce4b0c132f2baab67
# 65              Assam            Guwahati  4f153c4be4b0725fef6080c2
# 66              Assam            Guwahati  4f16cf6be4b0fd2953b69899
# 67         Chandigarh          Chandigarh  4b8a5453f964a520bb6832e3
# 68         Chandigarh          Chandigarh  4c022361f423a5936670ce16
# 69             Kerala  Thiruvananthapuram  4d77d03f013060fc81e79c05
# 70          Karnataka              Mysore  4ea98b949adf64e06c6a6f7e
# 71        Tamil Nadu                Salem  4c51357f1c67ef3b951311b9
# 72             Odisha        Bhubaneshwar  4da84de37aba67f9d9619c29
# 73        Maharashtra            Bhiwandi  4b5dc6e6f964a520166b29e3
# 74        Uttarakhand           Dehra Dun  4be57ff9d4f7c9b6ff712520
# 75        Tamil Nadu              Chennai  4c0bcc2299459521d98c74dd
# 76        West Bengal             Kolkata  4dfa2b8aae60f95f8225b9c9
#
#                        Name  Likes  Rating  Tips
# 0            Mainland China     10     7.8     7
# 1                         0      0     0.0     0
# 2            Chopstick City     11     8.4     4
# 3                  Big Boss     22     8.5     8
# 4                Golden Joy     20     8.4    12
# 5        Beijing Restaurant     20     8.3     9
# 6                  Yauatcha     15     8.3     5
# 7     Red Hot Chilli Pepper     15     8.3     4
# 8               Chinoiserie      7     7.9     6
# 9            Mainland China     41     8.0    17
# 10         O2 Hotel Kolkata     12     7.2     4
# 11              Wok n Grill     23     7.3    12
# 12                  Deja Vu      7     6.8     3
# 13                  Hawkers     15     8.4     6
# 14                  Nanking      6     7.2     8
# 15       Vismaya Restaurant     10     7.9     5
# 16                  Hawkers     15     8.4     6
# 17               China Town     11     7.5     7
# 18             China Valley     14     7.2     9
# 19        Wheels Restaurant     12     7.1    12
# 20                  Dim Sum     11     6.3     6
# 21                    Lhasa      4     7.4     3
# 22            Golden Dragon     15     8.5     7
# 23              WOK ON FiRE     26     8.2     9
# 24              Wok On Fire     27     8.1     7
# 25           Mainland China     23     8.2    11
# 26               Noodle Bar      9     7.7     9
# 27                    Lhasa      4     7.4     3
# 28                Confucius      4     6.9     2
# 29    Red Hot Chilli Pepper     13     6.7    12
# 30                Waterside     15     6.9    14
# 31           Mainland China     23     8.2    11
# 32               Noodle Bar      9     7.7     9
# 33                Ming Yang     28     8.9    13
# 34                  Hawkers     15     8.4     6
# 35               Golden Joy     20     8.4    12
# 36                 Yauatcha     15     8.3     5
# 37       Beijing Restaurant     20     8.3     9
# 38    Red Hot Chilli Pepper     15     8.3     4
# 39              Chinoiserie      7     7.9     6
# 40           Mainland China     41     8.0    17
# 41         O2 Hotel Kolkata     12     7.2     4
# 42              The Cascade      8     7.2     3
# 43                   Mekong     18     8.5     6
# 44                Waterside     15     6.9    14
# 45                 Big Boss     22     8.5     8
# 46                 Yauatcha     15     8.3     5
# 47               Golden Joy     20     8.4    12
# 48    Red Hot Chilli Pepper     15     8.3     4
# 49       Beijing Restaurant     20     8.3     9
# 50              Chinoiserie      7     7.9     6
# 51         O2 Hotel Kolkata     12     7.2     4
# 52            Golden Dragon     15     8.5     7
# 53              WOK ON FiRE     26     8.2     9
# 54              Wok On Fire     27     8.1     7
# 55               Yo ! China     12     6.2     8
# 56           Chopstick City     11     8.4     4
# 57                Ming Yang     28     8.9    13
# 58                  Hawkers     15     8.4     6
# 59              Zinq Lounge     12     7.2     7
# 60           Mainland China     41     8.0    17
# 61                  Hawkers     15     8.4     6
# 62           Mainland China     11     6.8     1
# 63              clock tower      7     7.6     3
# 64                    Lhasa      4     7.4     3
# 65                Confucius      4     6.9     2
# 66    Red Hot Chilli Pepper     13     6.7    12
# 67           Mainland China     23     8.2    11
# 68               Noodle Bar      9     7.7     9
# 69       Vismaya Restaurant     10     7.9     5
# 70                  Nanking      6     7.2     8
# 71    Green Park Restaurant      8     6.3     6
# 72           Mainland China     10     7.8     7
# 73                Ming Yang     28     8.9    13
# 74  Kalsang Friend's Corner     54     8.8    27
# 75             White Pepper      3     7.5     7
# 76                 Big Boss     22     8.5     8

# %%
rating_df.dtypes
# Out:
# State      object
# city       object
# ID         object
# Name       object
# Likes       int64
# Rating    float64
# Tips        int64
# dtype: object

# %%
# Resturant with maximum Likes
rating_df.iloc[rating_df['Likes'].idxmax()]
# Out:
# State                  Uttarakhand
# city                     Dehra Dun
# ID        4be57ff9d4f7c9b6ff712520
# Name       Kalsang Friend's Corner
# Likes                           54
# Rating                         8.8
# Tips                            27
# Name: 74, dtype: object

# %%
# Resturant with maximum Rating
rating_df.iloc[rating_df['Rating'].idxmax()]
# Out:
# State                  Maharashtra
# city                        Mumbai
# ID        4b5dc6e6f964a520166b29e3
# Name                     Ming Yang
# Likes                           28
# Rating                         8.9
# Tips                            13
# Name: 33, dtype: object

# %%
# Resturant with maximum Tips
rating_df.iloc[rating_df['Tips'].idxmax()]
# Out:
# State                  Uttarakhand
# city                     Dehra Dun
# ID        4be57ff9d4f7c9b6ff712520
# Name       Kalsang Friend's Corner
# Likes                           54
# Rating                         8.8
# Tips                            27
# Name: 74, dtype: object

# %% [markdown]
# ### List of Average Rating in all the cities.

# %%
city_stats=rating_df.groupby('city',as_index=False).mean()[['city','Rating']]
city_stats.columns=['city','Average Rating']

# %%
city_stats.sort_values(['Average Rating'],ascending=False).head(10)
# Out:
#          city  Average Rating
# 27     Mumbai             8.9
# 24     Kalyan             8.9
# 6    Bhiwandi             8.9
# 12  Dehra Dun             8.8
# 21  Hyderabad             8.5
# 32  New Delhi             8.4
# 18    Gurgaon             8.4
# 17  Ghaziabad             8.4
# 15  Faridabad             8.4
# 13      Delhi             8.4

# %% [markdown]
# ### List of Average Rating is all the States.

# %%
State_stats=rating_df.groupby('State',as_index=False).mean()[['State','Rating']]
State_stats.columns=['State','Average Rating']

# %%
State_stats.sort_values(['Average Rating'],ascending=False).head(10)
# Out:
#              State  Average Rating
# 17     Uttarakhand        8.800000
# 0   Andhra Pradesh        8.500000
# 12     Maharashtra        8.475000
# 4            Delhi        8.400000
# 16   Uttar Pradesh        8.400000
# 11  Madhya Pradesh        8.133333
# 6          Haryana        8.100000
# 3       Chandigarh        7.950000
# 5          Gujarat        7.925000
# 14          Odisha        7.800000

# %% [markdown]
# ### Plotting a graph for Average Rating of Chinese Restaurants for Each State.

# %%
plt.figure(figsize=(9,5), dpi = 100)
# title
plt.title('Average rating of Chinese Resturants for each State')
#On x-axis
plt.xlabel('State', fontsize = 15)
#On y-axis
plt.ylabel('Average Rating', fontsize=15)
#giving a bar plot
rating_df.groupby('State').mean()['Rating'].plot(kind='bar')
#legend
plt.legend()
#displays the plot
plt.show()

# %% [markdown]
# ### Selecting Cities With Average Rating > 8.5

# %%
city_stats_top=city_stats[city_stats['Average Rating']>=8.5]
city_stats_top.index = [0,1,2,3,4]
city_stats_top
# Out:
#         city  Average Rating
# 0   Bhiwandi             8.9
# 1  Dehra Dun             8.8
# 2  Hyderabad             8.5
# 3     Kalyan             8.9
# 4     Mumbai             8.9

# %%
# Merging with df to get Latitude and longitude for each City.
city_stats_top=pd.merge(city_stats_top,df, on='city')

# %%
# latitude = pd.Series([])
# longitude = pd.Series([])
# for i in range(0, len(city_stats_top)):
#     latitude[i] = geo_location(city_stats_top.city[i])[0]
#     longitude[i] = geo_location(city_stats_top.city[i])[1]

# city_stats_top.insert(2, "Latitude", latitude) 
# city_stats_top.insert(3, "Longitude", longitude)

# %%
city_stats_top = city_stats_top[['State', 'city', 'Latitude', 'Longitude', 'Average Rating']]
city_stats_top
# Out:
#             State       city   Latitude  Longitude  Average Rating
# 0     Maharashtra   Bhiwandi  19.300229  73.058813             8.9
# 1     Uttarakhand  Dehra Dun  30.324427  78.033922             8.8
# 2  Andhra Pradesh  Hyderabad  17.384052  78.456355             8.5
# 3     Maharashtra     Kalyan  19.243703  73.135537             8.9
# 4     Maharashtra     Mumbai  18.987807  72.836447             8.9

# %%
#INDIA-Map.
india_map = folium.Map(location=geo_location('India'), zoom_start=6)

# %%
# instantiate a feature group for the incidents in the dataframe
incidents = folium.map.FeatureGroup()

# loop through the neighborhood and add each to the feature group
for lat, lng, in city_stats_top[['Latitude','Longitude']].values:
    incidents.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius=10, # define how big you want the circle markers to be
            color='yellow',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )

# %%
city_stats_top['Label']=city_stats_top['city']+', '+city_stats_top['State']+'('+city_stats_top['Average Rating'].map(str)+')'
city_stats_top
# Out:
#             State       city   Latitude  Longitude  Average Rating  \
# 0     Maharashtra   Bhiwandi  19.300229  73.058813             8.9
# 1     Uttarakhand  Dehra Dun  30.324427  78.033922             8.8
# 2  Andhra Pradesh  Hyderabad  17.384052  78.456355             8.5
# 3     Maharashtra     Kalyan  19.243703  73.135537             8.9
# 4     Maharashtra     Mumbai  18.987807  72.836447             8.9
#
#                             Label
# 0      Bhiwandi, Maharashtra(8.9)
# 1     Dehra Dun, Uttarakhand(8.8)
# 2  Hyderabad, Andhra Pradesh(8.5)
# 3        Kalyan, Maharashtra(8.9)
# 4        Mumbai, Maharashtra(8.9)

# %%
# add pop-up text to each marker on the map
for lat, lng, label in city_stats_top[['Latitude','Longitude','Label']].values:
    folium.Marker([lat, lng], popup=label).add_to(india_map)        
# add incidents to map
india_map = india_map.add_child(incidents)
india_map.save('borough_rating.html')

# %%
india_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Function to get details of any category in any location.

# %%
def get_details(address, Place):
    Place_list = list()
    Category = pd.DataFrame(columns = ['ID', 'Name', 'Category'])

    # address = input('Enter Location:')
    # Place = input('Enter what you want to find:')

    lat = geo_location(address)[0]
    lng = geo_location(address)[1]
    venues = get_venues(lat,lng)

    for i in venues.Category:
            if(i.find(Place) != -1):
                Place_list.append(i)

    for i in range(0,len(Place_list)):
        Category = Category.append(venues[venues['Category'] == Place_list[i]])

    column_names=['ID','Name','Likes','Rating','Tips']
    Category_stats=pd.DataFrame(columns=column_names)
    count=1


    for row in Category[0:11].values.tolist():
        ID,Name,cat=row
        try:
            venue_details=get_venue_details(ID)
            id,name,likes,rating,tips=venue_details.values.tolist()[0]
        except IndexError:
            print('No data available for id=',ID)
            id,name,likes,rating,tips=[0]*5

        Category_stats = Category_stats.append({'ID': id,
                                                    'Name' : name,
                                                    'Likes' : likes,
                                                    'Rating' : rating,
                                                    'Tips' : tips
                                                   }, ignore_index=True)
        count+=1

    return Category_stats

# %%
get_details('kandivali', 'Restaurant')
# Out:
#                           ID                               Name Likes  Rating  \
# 0   4c42c88ed7fad13afaac09da                Indigo Delicatessen    90     8.5
# 1   51fa1f52ccdae6540ad807b4             Hard Rock Cafe Andheri   389     8.4
# 2   4d04fc8b30a58cfaead2a2e7                  Mahesh Lunch Home   120     8.7
# 3   4d2ca96ec406721eb5bd96b6                           Soul Fry    55     8.6
# 4   4eff27b1e5faf2869b1aba6f                          Jai Jawan    25     8.3
# 5   4bfe4e1855539c7488d2bcf3                Jai Hind Lunch Home    23     8.9
# 6   4beaed8a415e20a130a6e5bb                 Fareed Seekh Kebab    15     8.3
# 7   4b65a8ecf964a52043f82ae3                        Urban Tadka    40     8.4
# 8   4be958699a54a593eaee0a11  Punjab Sweet House And Restaurant    41     8.9
# 9   4b5be651f964a520501c29e3                      Vishwa Bharti    16     8.4
# 10  4e64c78ed4c06542abf0128b                     Pritam's Dhaba    11     8.3
#
#    Tips
# 0    54
# 1    76
# 2    41
# 3    33
# 4    17
# 5     5
# 6    10
# 7    26
# 8    27
# 9     9
# 10    3

# %% [markdown]
# ## CONCLUSION.
# ### 1.Following are the places in India where we can find great Chinese Restaurants:Bhiwandi (Maharashtra), Dehra Dun (Uttarkhand), Hyderabad (Andhra Pradesh), Kalyan (Maharashtra), Mumbai (Maharashtra)
#
# ### 2.Bhiwandi (Maharashtra) , Dehra Dun (Uttarkhand) and Hyderabad (Andhra Pradesh) are some locations in India for good Chinese Restaurants.
#
# ### 3.Andhra Pradesh and Uttarkhand have Potential Chinese Market.
#
# ### 4.Bihar ranks last in average rating of Chinese Restaurants.
#
# ### 5.Mumbai is the best place to stay if you love Chinese restaurants.
